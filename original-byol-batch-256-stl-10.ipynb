# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets, models
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn import preprocessing
import numpy as np
import copy
import os
import time

# PART 0: LARS Optimizer Implementation
class LARS(torch.optim.Optimizer):
    def __init__(self, params, lr, momentum=0.9, weight_decay=1e-4, trust_coefficient=0.001, eps=1e-8):
        defaults = dict(lr=lr, momentum=momentum, weight_decay=weight_decay,
                        trust_coefficient=trust_coefficient, eps=eps)
        super(LARS, self).__init__(params, defaults)

    @torch.no_grad()
    def step(self, closure=None):
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()

        for group in self.param_groups:
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            trust_coefficient = group['trust_coefficient']
            eps = group['eps']

            for p in group['params']:
                if p.grad is None:
                    continue
                d_p = p.grad

                p_norm = torch.norm(p.data)
                g_norm = torch.norm(d_p.data)

                if p_norm > 0 and g_norm > 0:
                    lars_lr = trust_coefficient * p_norm / (g_norm + p_norm * weight_decay + eps)
                    d_p = d_p.add(p, alpha=weight_decay)
                    d_p *= lars_lr

                param_state = self.state[p]
                if 'momentum_buffer' not in param_state:
                    buf = param_state['momentum_buffer'] = torch.clone(d_p).detach()
                else:
                    buf = param_state['momentum_buffer']
                    buf.mul_(momentum).add_(d_p)

                p.add_(buf, alpha=-group['lr'])
        return loss

# PART 1: Data Augmentation
class GaussianBlur(object):
    def __init__(self, kernel_size):
        radius = kernel_size // 2
        kernel_size = radius * 2 + 1
        self.blur_h = nn.Conv2d(3, 3, kernel_size=(kernel_size, 1), stride=1, padding=0, bias=False, groups=3)
        self.blur_v = nn.Conv2d(3, 3, kernel_size=(1, kernel_size), stride=1, padding=0, bias=False, groups=3)
        self.k, self.r = kernel_size, radius
        self.blur = nn.Sequential(nn.ReflectionPad2d(radius), self.blur_h, self.blur_v)
        self.pil_to_tensor = transforms.ToTensor()
        self.tensor_to_pil = transforms.ToPILImage()

    def __call__(self, img):
        img = self.pil_to_tensor(img).unsqueeze(0)
        sigma = np.random.uniform(0.1, 2.0)
        x = np.arange(-self.r, self.r + 1)
        x = np.exp(-np.power(x, 2) / (2 * sigma * sigma))
        x = x / x.sum()
        x = torch.from_numpy(x).view(1, -1).repeat(3, 1).float()
        self.blur_h.weight.data.copy_(x.view(3, 1, self.k, 1))
        self.blur_v.weight.data.copy_(x.view(3, 1, 1, self.k))
        with torch.no_grad():
            img = self.blur(img).squeeze()
        return self.tensor_to_pil(img)

class MultiViewDataInjector(object):
    def __init__(self, transform_list):
        self.transforms = transform_list
    def __call__(self, sample):
        return [t(sample) for t in self.transforms]

def get_simclr_data_transforms(input_shape, s=1):
    size = input_shape[0]
    color_jitter = transforms.ColorJitter(0.8 * s, 0.8 * s, 0.8 * s, 0.2 * s)
    return transforms.Compose([
        transforms.RandomResizedCrop(size=size),
        transforms.RandomHorizontalFlip(),
        transforms.RandomApply([color_jitter], p=0.8),
        transforms.RandomGrayscale(p=0.2),
        GaussianBlur(kernel_size=int(0.1 * size)),
        transforms.ToTensor()
    ])

# PART 2: Model Architectures
class MLPHead(nn.Module):
    def __init__(self, in_channels, mlp_hidden_size, projection_size):
        super(MLPHead, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(in_channels, mlp_hidden_size),
            nn.BatchNorm1d(mlp_hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(mlp_hidden_size, projection_size)
        )
    def forward(self, x):
        return self.net(x)

class ResNetEncoder(torch.nn.Module):
    def __init__(self, name, projection_head):
        super(ResNetEncoder, self).__init__()
        resnet = models.resnet50(weights=None) if name == 'resnet50' else models.resnet18(weights=None)
        self.encoder = torch.nn.Sequential(*list(resnet.children())[:-1])
        self.projection = MLPHead(in_channels=resnet.fc.in_features, **projection_head)

    def forward(self, x):
        h = self.encoder(x)
        h = h.view(h.shape[0], -1)
        return self.projection(h)

# PART 3: Original BYOL Trainer
class BYOLTrainerRefined:
    def __init__(self, online_net, target_net, predictor, optimizer, device, **params):
        self.online_net = online_net
        self.target_net = target_net
        self.predictor = predictor
        self.optimizer = optimizer
        self.device = device
        self.max_epochs, self.m = params['max_epochs'], params['m']
        self.batch_size, self.num_workers = params['batch_size'], params['num_workers']
        self.writer = SummaryWriter()

    def _update_target(self):
        for p_o, p_t in zip(self.online_net.parameters(), self.target_net.parameters()):
            p_t.data = p_t.data * self.m + p_o.data * (1. - self.m)

    def regression_loss(self, x, y):
        x, y = F.normalize(x, dim=1), F.normalize(y, dim=1)
        return 2 - 2 * (x * y).sum(dim=-1)

    def train(self, train_dataset):
        loader = DataLoader(train_dataset, batch_size=self.batch_size, num_workers=self.num_workers, drop_last=True, shuffle=True)
        for epoch in range(self.max_epochs):
            for i, ((view_1, view_2), _) in enumerate(loader):
                view_1, view_2 = view_1.to(self.device), view_2.to(self.device)

                # Online predictions
                p1 = self.predictor(self.online_net(view_1))
                p2 = self.predictor(self.online_net(view_2))

                # Target projections (Stop Gradient)
                with torch.no_grad():
                    t1 = self.target_net(view_2)
                    t2 = self.target_net(view_1)

                # Symmetric BYOL Loss
                loss = (self.regression_loss(p1, t1) + self.regression_loss(p2, t2)).mean()

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

                self._update_target()

                if i % 10 == 0:
                    print(f"Epoch {epoch}, Iter {i}, BYOL Loss (LARS): {loss.item():.4f}")

        save_path = os.path.join(self.writer.log_dir, 'original_byol_lars.pth')
        torch.save({'online_state': self.online_net.state_dict()}, save_path)
        print(f"Weights saved to {save_path}")
        return save_path

# PART 4: Linear Evaluation
def run_linear_evaluation(encoder, train_loader, test_loader, device):
    print("\n--- Linear Evaluation (Frozen ResNet-50) ---")
    encoder.eval()

    def extract_features(model, loader):
        x_out, y_out = [], []
        for img, lbl in loader:
            with torch.no_grad():
                img = img.to(device)
                f = model(img).view(img.size(0), -1).cpu()
                x_out.append(f); y_out.extend(lbl.numpy())
        return torch.cat(x_out, dim=0), torch.tensor(y_out)

    x_train, y_train = extract_features(encoder, train_loader)
    x_test, y_test = extract_features(encoder, test_loader)

    scaler = preprocessing.StandardScaler()
    x_train_scaled = torch.from_numpy(scaler.fit_transform(x_train)).float()
    x_test_scaled = torch.from_numpy(scaler.transform(x_test)).float()

    loader = DataLoader(torch.utils.data.TensorDataset(x_train_scaled, y_train), batch_size=64, shuffle=True)
    classifier = torch.nn.Linear(x_train_scaled.shape[1], 10).to(device)
    optimizer = torch.optim.Adam(classifier.parameters(), lr=3e-4)

    for epoch in range(100):
        for x_b, y_b in loader:
            optimizer.zero_grad()
            F.cross_entropy(classifier(x_b.to(device)), y_b.to(device)).backward()
            optimizer.step()

        if epoch % 10 == 0:
            with torch.no_grad():
                preds = torch.argmax(classifier(x_test_scaled.to(device)), dim=1)
                acc = (preds == y_test.to(device)).float().mean()
                print(f"Epoch {epoch} | Accuracy: {acc.item()*100:.2f}%")

# PART 5: Execution
if __name__ == '__main__':
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # 1. Initialize Online and Target Networks (ResNet-50)

    online_net = ResNetEncoder('resnet50', {'mlp_hidden_size': 4096, 'projection_size': 256}).to(device)
    target_net = copy.deepcopy(online_net)
    predictor = MLPHead(256, 4096, 256).to(device)

    # Initialize targets with stop-gradient
    for po, pt in zip(online_net.parameters(), target_net.parameters()):
        pt.data.copy_(po.data); pt.requires_grad = False

    # 2. Configure LARS Optimizer with lr=0.02
    optimizer = LARS(
        list(online_net.parameters()) + list(predictor.parameters()),
        lr=0.02,
        momentum=0.9,
        weight_decay=1e-6
    )

    # 3. Data Preparation (STL-10)
    transform = get_simclr_data_transforms((96, 96, 3))
    train_ds = datasets.STL10('./data', split='train', download=True,
                               transform=MultiViewDataInjector([transform, transform]))

    # 4. Pre-training
    trainer = BYOLTrainerRefined(online_net, target_net, predictor, optimizer, device,
                                 max_epochs=500, m=0.996, batch_size=256, num_workers=2)
    trainer.train(train_ds)

    # 5. Final Evaluation
    eval_t = transforms.Compose([transforms.ToTensor()])
    tr_ldr = DataLoader(datasets.STL10('./data', split='train', transform=eval_t), batch_size=256)
    te_ldr = DataLoader(datasets.STL10('./data', split='test', transform=eval_t), batch_size=256)

    run_linear_evaluation(online_net.encoder, tr_ldr, te_ldr, device)
# Out:
# 2026-03-19 12:59:33.673559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773925173.857230      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773925173.910493      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773925174.359004      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773925174.359040      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773925174.359043      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773925174.359046      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 100%|██████████| 2.64G/2.64G [04:16<00:00, 10.3MB/s]
# Epoch 0, Iter 0, BYOL Loss (LARS): 4.2560
# Epoch 0, Iter 10, BYOL Loss (LARS): 3.9631
# Epoch 1, Iter 0, BYOL Loss (LARS): 3.6463
# Epoch 1, Iter 10, BYOL Loss (LARS): 3.2584
# Epoch 2, Iter 0, BYOL Loss (LARS): 2.9381
# Epoch 2, Iter 10, BYOL Loss (LARS): 2.6380
# Epoch 3, Iter 0, BYOL Loss (LARS): 2.4313
# Epoch 3, Iter 10, BYOL Loss (LARS): 2.1945
# Epoch 4, Iter 0, BYOL Loss (LARS): 2.1203
# Epoch 4, Iter 10, BYOL Loss (LARS): 2.0010
# Epoch 5, Iter 0, BYOL Loss (LARS): 1.8503
# Epoch 5, Iter 10, BYOL Loss (LARS): 1.8182
# Epoch 6, Iter 0, BYOL Loss (LARS): 1.6965
# Epoch 6, Iter 10, BYOL Loss (LARS): 1.6443
# Epoch 7, Iter 0, BYOL Loss (LARS): 1.6013
# Epoch 7, Iter 10, BYOL Loss (LARS): 1.6132
# Epoch 8, Iter 0, BYOL Loss (LARS): 1.5763
# Epoch 8, Iter 10, BYOL Loss (LARS): 1.5300
# Epoch 9, Iter 0, BYOL Loss (LARS): 1.5404
# Epoch 9, Iter 10, BYOL Loss (LARS): 1.4995
# Epoch 10, Iter 0, BYOL Loss (LARS): 1.4981
# Epoch 10, Iter 10, BYOL Loss (LARS): 1.4651
# Epoch 11, Iter 0, BYOL Loss (LARS): 1.5193
# Epoch 11, Iter 10, BYOL Loss (LARS): 1.4100
# Epoch 12, Iter 0, BYOL Loss (LARS): 1.4376
# Epoch 12, Iter 10, BYOL Loss (LARS): 1.4149
# Epoch 13, Iter 0, BYOL Loss (LARS): 1.2978
# Epoch 13, Iter 10, BYOL Loss (LARS): 1.4214
# Epoch 14, Iter 0, BYOL Loss (LARS): 1.2791
# Epoch 14, Iter 10, BYOL Loss (LARS): 1.3685
# Epoch 15, Iter 0, BYOL Loss (LARS): 1.2563
# Epoch 15, Iter 10, BYOL Loss (LARS): 1.3032
# Epoch 16, Iter 0, BYOL Loss (LARS): 1.2800
# Epoch 16, Iter 10, BYOL Loss (LARS): 1.2465
# Epoch 17, Iter 0, BYOL Loss (LARS): 1.2073
# Epoch 17, Iter 10, BYOL Loss (LARS): 1.2010
# Epoch 18, Iter 0, BYOL Loss (LARS): 1.1686
# Epoch 18, Iter 10, BYOL Loss (LARS): 1.2287
# Epoch 19, Iter 0, BYOL Loss (LARS): 1.1694
# Epoch 19, Iter 10, BYOL Loss (LARS): 1.1658
# Epoch 20, Iter 0, BYOL Loss (LARS): 1.1482
# Epoch 20, Iter 10, BYOL Loss (LARS): 1.2003
# Epoch 21, Iter 0, BYOL Loss (LARS): 1.0269
# Epoch 21, Iter 10, BYOL Loss (LARS): 1.0188
# Epoch 22, Iter 0, BYOL Loss (LARS): 1.0657
# Epoch 22, Iter 10, BYOL Loss (LARS): 1.0880
# Epoch 23, Iter 0, BYOL Loss (LARS): 1.1019
# Epoch 23, Iter 10, BYOL Loss (LARS): 1.0264
# Epoch 24, Iter 0, BYOL Loss (LARS): 1.0128
# Epoch 24, Iter 10, BYOL Loss (LARS): 1.1545
# Epoch 25, Iter 0, BYOL Loss (LARS): 1.0572
# Epoch 25, Iter 10, BYOL Loss (LARS): 1.0529
# Epoch 26, Iter 0, BYOL Loss (LARS): 1.1244
# Epoch 26, Iter 10, BYOL Loss (LARS): 1.0477
# Epoch 27, Iter 0, BYOL Loss (LARS): 0.9492
# Epoch 27, Iter 10, BYOL Loss (LARS): 1.0633
# Epoch 28, Iter 0, BYOL Loss (LARS): 0.9643
# Epoch 28, Iter 10, BYOL Loss (LARS): 0.9621
# Epoch 29, Iter 0, BYOL Loss (LARS): 1.0202
# Epoch 29, Iter 10, BYOL Loss (LARS): 1.0681
# Epoch 30, Iter 0, BYOL Loss (LARS): 0.9948
# Epoch 30, Iter 10, BYOL Loss (LARS): 0.9673
# Epoch 31, Iter 0, BYOL Loss (LARS): 0.9203
# Epoch 31, Iter 10, BYOL Loss (LARS): 1.1056
# Epoch 32, Iter 0, BYOL Loss (LARS): 0.9918
# Epoch 32, Iter 10, BYOL Loss (LARS): 0.9740
# Epoch 33, Iter 0, BYOL Loss (LARS): 1.0125
# Epoch 33, Iter 10, BYOL Loss (LARS): 0.8722
# Epoch 34, Iter 0, BYOL Loss (LARS): 0.9925
# Epoch 34, Iter 10, BYOL Loss (LARS): 0.9077
# Epoch 35, Iter 0, BYOL Loss (LARS): 0.9398
# Epoch 35, Iter 10, BYOL Loss (LARS): 0.9263
# Epoch 36, Iter 0, BYOL Loss (LARS): 0.9517
# Epoch 36, Iter 10, BYOL Loss (LARS): 0.9901
# Epoch 37, Iter 0, BYOL Loss (LARS): 0.9224
# Epoch 37, Iter 10, BYOL Loss (LARS): 0.9711
# Epoch 38, Iter 0, BYOL Loss (LARS): 0.9634
# Epoch 38, Iter 10, BYOL Loss (LARS): 0.8680
# Epoch 39, Iter 0, BYOL Loss (LARS): 0.9192
# Epoch 39, Iter 10, BYOL Loss (LARS): 0.9276
# Epoch 40, Iter 0, BYOL Loss (LARS): 0.8875
# Epoch 40, Iter 10, BYOL Loss (LARS): 0.9013
# Epoch 41, Iter 0, BYOL Loss (LARS): 0.9809
# Epoch 41, Iter 10, BYOL Loss (LARS): 0.8920
# Epoch 42, Iter 0, BYOL Loss (LARS): 0.8513
# Epoch 42, Iter 10, BYOL Loss (LARS): 0.8334
# Epoch 43, Iter 0, BYOL Loss (LARS): 0.8776
# Epoch 43, Iter 10, BYOL Loss (LARS): 0.8623
# Epoch 44, Iter 0, BYOL Loss (LARS): 0.9702
# Epoch 44, Iter 10, BYOL Loss (LARS): 1.0190
# Epoch 45, Iter 0, BYOL Loss (LARS): 0.8729
# Epoch 45, Iter 10, BYOL Loss (LARS): 0.9073
# Epoch 46, Iter 0, BYOL Loss (LARS): 0.8464
# Epoch 46, Iter 10, BYOL Loss (LARS): 0.8671
# Epoch 47, Iter 0, BYOL Loss (LARS): 0.8701
# Epoch 47, Iter 10, BYOL Loss (LARS): 0.8545
# Epoch 48, Iter 0, BYOL Loss (LARS): 0.8405
# Epoch 48, Iter 10, BYOL Loss (LARS): 0.8997
# Epoch 49, Iter 0, BYOL Loss (LARS): 0.7458
# Epoch 49, Iter 10, BYOL Loss (LARS): 0.9106
# Epoch 50, Iter 0, BYOL Loss (LARS): 0.8850
# Epoch 50, Iter 10, BYOL Loss (LARS): 0.8219
# Epoch 51, Iter 0, BYOL Loss (LARS): 0.8970
# Epoch 51, Iter 10, BYOL Loss (LARS): 0.7651
# Epoch 52, Iter 0, BYOL Loss (LARS): 0.9279
# Epoch 52, Iter 10, BYOL Loss (LARS): 0.8443
# Epoch 53, Iter 0, BYOL Loss (LARS): 0.8219
# Epoch 53, Iter 10, BYOL Loss (LARS): 1.0216
# Epoch 54, Iter 0, BYOL Loss (LARS): 0.9103
# Epoch 54, Iter 10, BYOL Loss (LARS): 0.9268
# Epoch 55, Iter 0, BYOL Loss (LARS): 0.8838
# Epoch 55, Iter 10, BYOL Loss (LARS): 0.8559
# Epoch 56, Iter 0, BYOL Loss (LARS): 0.8768
# Epoch 56, Iter 10, BYOL Loss (LARS): 0.8406
# Epoch 57, Iter 0, BYOL Loss (LARS): 0.8971
# Epoch 57, Iter 10, BYOL Loss (LARS): 0.8356
# Epoch 58, Iter 0, BYOL Loss (LARS): 0.9315
# Epoch 58, Iter 10, BYOL Loss (LARS): 0.9873
# Epoch 59, Iter 0, BYOL Loss (LARS): 0.8226
# Epoch 59, Iter 10, BYOL Loss (LARS): 0.9071
# Epoch 60, Iter 0, BYOL Loss (LARS): 0.8191
# Epoch 60, Iter 10, BYOL Loss (LARS): 0.8275
# Epoch 61, Iter 0, BYOL Loss (LARS): 0.8604
# Epoch 61, Iter 10, BYOL Loss (LARS): 0.7684
# Epoch 62, Iter 0, BYOL Loss (LARS): 0.8517
# Epoch 62, Iter 10, BYOL Loss (LARS): 0.7857
# Epoch 63, Iter 0, BYOL Loss (LARS): 0.8498
# Epoch 63, Iter 10, BYOL Loss (LARS): 0.8130
# Epoch 64, Iter 0, BYOL Loss (LARS): 0.9407
# Epoch 64, Iter 10, BYOL Loss (LARS): 0.8350
# Epoch 65, Iter 0, BYOL Loss (LARS): 0.9096
# Epoch 65, Iter 10, BYOL Loss (LARS): 0.8112
# Epoch 66, Iter 0, BYOL Loss (LARS): 0.9217
# Epoch 66, Iter 10, BYOL Loss (LARS): 0.8885
# Epoch 67, Iter 0, BYOL Loss (LARS): 0.8239
# Epoch 67, Iter 10, BYOL Loss (LARS): 0.8324
# Epoch 68, Iter 0, BYOL Loss (LARS): 0.7770
# Epoch 68, Iter 10, BYOL Loss (LARS): 0.8086
# Epoch 69, Iter 0, BYOL Loss (LARS): 0.8644
# Epoch 69, Iter 10, BYOL Loss (LARS): 0.9342
# Epoch 70, Iter 0, BYOL Loss (LARS): 0.7721
# Epoch 70, Iter 10, BYOL Loss (LARS): 0.7766
# Epoch 71, Iter 0, BYOL Loss (LARS): 0.8538
# Epoch 71, Iter 10, BYOL Loss (LARS): 0.8772
# Epoch 72, Iter 0, BYOL Loss (LARS): 0.8992
# Epoch 72, Iter 10, BYOL Loss (LARS): 0.7908
# Epoch 73, Iter 0, BYOL Loss (LARS): 0.7869
# Epoch 73, Iter 10, BYOL Loss (LARS): 0.9481
# Epoch 74, Iter 0, BYOL Loss (LARS): 0.8512
# Epoch 74, Iter 10, BYOL Loss (LARS): 0.8456
# Epoch 75, Iter 0, BYOL Loss (LARS): 0.8596
# Epoch 75, Iter 10, BYOL Loss (LARS): 0.8526
# Epoch 76, Iter 0, BYOL Loss (LARS): 0.8236
# Epoch 76, Iter 10, BYOL Loss (LARS): 0.8319
# Epoch 77, Iter 0, BYOL Loss (LARS): 0.8419
# Epoch 77, Iter 10, BYOL Loss (LARS): 0.7517
# Epoch 78, Iter 0, BYOL Loss (LARS): 0.8315
# Epoch 78, Iter 10, BYOL Loss (LARS): 0.8170
# Epoch 79, Iter 0, BYOL Loss (LARS): 0.8743
# Epoch 79, Iter 10, BYOL Loss (LARS): 0.8657
# Epoch 80, Iter 0, BYOL Loss (LARS): 0.8479
# Epoch 80, Iter 10, BYOL Loss (LARS): 0.9231
# Epoch 81, Iter 0, BYOL Loss (LARS): 0.7780
# Epoch 81, Iter 10, BYOL Loss (LARS): 0.8200
# Epoch 82, Iter 0, BYOL Loss (LARS): 0.7783
# Epoch 82, Iter 10, BYOL Loss (LARS): 0.8626
# Epoch 83, Iter 0, BYOL Loss (LARS): 0.7928
# Epoch 83, Iter 10, BYOL Loss (LARS): 0.8025
# Epoch 84, Iter 0, BYOL Loss (LARS): 0.8116
# Epoch 84, Iter 10, BYOL Loss (LARS): 0.7531
# Epoch 85, Iter 0, BYOL Loss (LARS): 0.7763
# Epoch 85, Iter 10, BYOL Loss (LARS): 0.8198
# Epoch 86, Iter 0, BYOL Loss (LARS): 0.9123
# Epoch 86, Iter 10, BYOL Loss (LARS): 0.8523
# Epoch 87, Iter 0, BYOL Loss (LARS): 0.8212
# Epoch 87, Iter 10, BYOL Loss (LARS): 0.7511
# Epoch 88, Iter 0, BYOL Loss (LARS): 0.8057
# Epoch 88, Iter 10, BYOL Loss (LARS): 0.8641
# Epoch 89, Iter 0, BYOL Loss (LARS): 0.9482
# Epoch 89, Iter 10, BYOL Loss (LARS): 0.7730
# Epoch 90, Iter 0, BYOL Loss (LARS): 0.7762
# Epoch 90, Iter 10, BYOL Loss (LARS): 0.8776
# Epoch 91, Iter 0, BYOL Loss (LARS): 0.7763
# Epoch 91, Iter 10, BYOL Loss (LARS): 0.8327
# Epoch 92, Iter 0, BYOL Loss (LARS): 0.8698
# Epoch 92, Iter 10, BYOL Loss (LARS): 0.8099
# Epoch 93, Iter 0, BYOL Loss (LARS): 0.7597
# Epoch 93, Iter 10, BYOL Loss (LARS): 0.8068
# Epoch 94, Iter 0, BYOL Loss (LARS): 0.8127
# Epoch 94, Iter 10, BYOL Loss (LARS): 0.8838
# Epoch 95, Iter 0, BYOL Loss (LARS): 0.8427
# Epoch 95, Iter 10, BYOL Loss (LARS): 0.7955
# Epoch 96, Iter 0, BYOL Loss (LARS): 0.7681
# Epoch 96, Iter 10, BYOL Loss (LARS): 0.7397
# Epoch 97, Iter 0, BYOL Loss (LARS): 0.7277
# Epoch 97, Iter 10, BYOL Loss (LARS): 0.8315
# Epoch 98, Iter 0, BYOL Loss (LARS): 0.9079
# Epoch 98, Iter 10, BYOL Loss (LARS): 0.8472
# Epoch 99, Iter 0, BYOL Loss (LARS): 0.8775
# Epoch 99, Iter 10, BYOL Loss (LARS): 0.7567
# Epoch 100, Iter 0, BYOL Loss (LARS): 0.8017
# Epoch 100, Iter 10, BYOL Loss (LARS): 0.8485
# Epoch 101, Iter 0, BYOL Loss (LARS): 0.7497
# Epoch 101, Iter 10, BYOL Loss (LARS): 0.9530
# Epoch 102, Iter 0, BYOL Loss (LARS): 0.8150
# Epoch 102, Iter 10, BYOL Loss (LARS): 0.9009
# Epoch 103, Iter 0, BYOL Loss (LARS): 0.8786
# Epoch 103, Iter 10, BYOL Loss (LARS): 0.8022
# Epoch 104, Iter 0, BYOL Loss (LARS): 0.8221
# Epoch 104, Iter 10, BYOL Loss (LARS): 0.8411
# Epoch 105, Iter 0, BYOL Loss (LARS): 0.8372
# Epoch 105, Iter 10, BYOL Loss (LARS): 0.8597
# Epoch 106, Iter 0, BYOL Loss (LARS): 0.7722
# Epoch 106, Iter 10, BYOL Loss (LARS): 0.9557
# Epoch 107, Iter 0, BYOL Loss (LARS): 0.8967
# Epoch 107, Iter 10, BYOL Loss (LARS): 0.8849
# Epoch 108, Iter 0, BYOL Loss (LARS): 0.8192
# Epoch 108, Iter 10, BYOL Loss (LARS): 0.8503
# Epoch 109, Iter 0, BYOL Loss (LARS): 0.8609
# Epoch 109, Iter 10, BYOL Loss (LARS): 0.7812
# Epoch 110, Iter 0, BYOL Loss (LARS): 0.9188
# Epoch 110, Iter 10, BYOL Loss (LARS): 0.8756
# Epoch 111, Iter 0, BYOL Loss (LARS): 0.8939
# Epoch 111, Iter 10, BYOL Loss (LARS): 0.9294
# Epoch 112, Iter 0, BYOL Loss (LARS): 0.8050
# Epoch 112, Iter 10, BYOL Loss (LARS): 0.7715
# Epoch 113, Iter 0, BYOL Loss (LARS): 0.8716
# Epoch 113, Iter 10, BYOL Loss (LARS): 0.8242
# Epoch 114, Iter 0, BYOL Loss (LARS): 0.8238
# Epoch 114, Iter 10, BYOL Loss (LARS): 0.8501
# Epoch 115, Iter 0, BYOL Loss (LARS): 0.8929
# Epoch 115, Iter 10, BYOL Loss (LARS): 0.8454
# Epoch 116, Iter 0, BYOL Loss (LARS): 0.8788
# Epoch 116, Iter 10, BYOL Loss (LARS): 0.8988
# Epoch 117, Iter 0, BYOL Loss (LARS): 0.8071
# Epoch 117, Iter 10, BYOL Loss (LARS): 0.8948
# Epoch 118, Iter 0, BYOL Loss (LARS): 0.7713
# Epoch 118, Iter 10, BYOL Loss (LARS): 0.8955
# Epoch 119, Iter 0, BYOL Loss (LARS): 0.9417
# Epoch 119, Iter 10, BYOL Loss (LARS): 0.7567
# Epoch 120, Iter 0, BYOL Loss (LARS): 0.8018
# Epoch 120, Iter 10, BYOL Loss (LARS): 0.9134
# Epoch 121, Iter 0, BYOL Loss (LARS): 0.9520
# Epoch 121, Iter 10, BYOL Loss (LARS): 0.8053
# Epoch 122, Iter 0, BYOL Loss (LARS): 0.8543
# Epoch 122, Iter 10, BYOL Loss (LARS): 0.9430
# Epoch 123, Iter 0, BYOL Loss (LARS): 0.8379
# Epoch 123, Iter 10, BYOL Loss (LARS): 0.7699
# Epoch 124, Iter 0, BYOL Loss (LARS): 0.7942
# Epoch 124, Iter 10, BYOL Loss (LARS): 0.8668
# Epoch 125, Iter 0, BYOL Loss (LARS): 0.8053
# Epoch 125, Iter 10, BYOL Loss (LARS): 0.8766
# Epoch 126, Iter 0, BYOL Loss (LARS): 0.9355
# Epoch 126, Iter 10, BYOL Loss (LARS): 0.8849
# Epoch 127, Iter 0, BYOL Loss (LARS): 0.8589
# Epoch 127, Iter 10, BYOL Loss (LARS): 0.8763
# Epoch 128, Iter 0, BYOL Loss (LARS): 0.7638
# Epoch 128, Iter 10, BYOL Loss (LARS): 0.9687
# Epoch 129, Iter 0, BYOL Loss (LARS): 0.9299
# Epoch 129, Iter 10, BYOL Loss (LARS): 0.7340
# Epoch 130, Iter 0, BYOL Loss (LARS): 0.8820
# Epoch 130, Iter 10, BYOL Loss (LARS): 0.9260
# Epoch 131, Iter 0, BYOL Loss (LARS): 0.7736
# Epoch 131, Iter 10, BYOL Loss (LARS): 0.9961
# Epoch 132, Iter 0, BYOL Loss (LARS): 0.7651
# Epoch 132, Iter 10, BYOL Loss (LARS): 0.8621
# Epoch 133, Iter 0, BYOL Loss (LARS): 0.7323
# Epoch 133, Iter 10, BYOL Loss (LARS): 0.9714
# Epoch 134, Iter 0, BYOL Loss (LARS): 0.8079
# Epoch 134, Iter 10, BYOL Loss (LARS): 0.9154
# Epoch 135, Iter 0, BYOL Loss (LARS): 0.9107
# Epoch 135, Iter 10, BYOL Loss (LARS): 0.8982
# Epoch 136, Iter 0, BYOL Loss (LARS): 0.8127
# Epoch 136, Iter 10, BYOL Loss (LARS): 0.9193
# Epoch 137, Iter 0, BYOL Loss (LARS): 0.8890
# Epoch 137, Iter 10, BYOL Loss (LARS): 0.8835
# Epoch 138, Iter 0, BYOL Loss (LARS): 0.7896
# Epoch 138, Iter 10, BYOL Loss (LARS): 0.9256
# Epoch 139, Iter 0, BYOL Loss (LARS): 0.8623
# Epoch 139, Iter 10, BYOL Loss (LARS): 0.9400
# Epoch 140, Iter 0, BYOL Loss (LARS): 0.8669
# Epoch 140, Iter 10, BYOL Loss (LARS): 0.8982
# Epoch 141, Iter 0, BYOL Loss (LARS): 0.8172
# Epoch 141, Iter 10, BYOL Loss (LARS): 0.7656
# Epoch 142, Iter 0, BYOL Loss (LARS): 0.8839
# Epoch 142, Iter 10, BYOL Loss (LARS): 0.7758
# Epoch 143, Iter 0, BYOL Loss (LARS): 0.8780
# Epoch 143, Iter 10, BYOL Loss (LARS): 0.8049
# Epoch 144, Iter 0, BYOL Loss (LARS): 0.9151
# Epoch 144, Iter 10, BYOL Loss (LARS): 0.9234
# Epoch 145, Iter 0, BYOL Loss (LARS): 0.7540
# Epoch 145, Iter 10, BYOL Loss (LARS): 0.8218
# Epoch 146, Iter 0, BYOL Loss (LARS): 0.7963
# Epoch 146, Iter 10, BYOL Loss (LARS): 0.9795
# Epoch 147, Iter 0, BYOL Loss (LARS): 0.8449
# Epoch 147, Iter 10, BYOL Loss (LARS): 0.9826
# Epoch 148, Iter 0, BYOL Loss (LARS): 0.8691
# Epoch 148, Iter 10, BYOL Loss (LARS): 0.8963
# Epoch 149, Iter 0, BYOL Loss (LARS): 0.8363
# Epoch 149, Iter 10, BYOL Loss (LARS): 1.0102
# Epoch 150, Iter 0, BYOL Loss (LARS): 0.8046
# Epoch 150, Iter 10, BYOL Loss (LARS): 0.8518
# Epoch 151, Iter 0, BYOL Loss (LARS): 0.9180
# Epoch 151, Iter 10, BYOL Loss (LARS): 0.8422
# Epoch 152, Iter 0, BYOL Loss (LARS): 0.9379
# Epoch 152, Iter 10, BYOL Loss (LARS): 0.7581
# Epoch 153, Iter 0, BYOL Loss (LARS): 0.9136
# Epoch 153, Iter 10, BYOL Loss (LARS): 0.7452
# Epoch 154, Iter 0, BYOL Loss (LARS): 0.7596
# Epoch 154, Iter 10, BYOL Loss (LARS): 0.9124
# Epoch 155, Iter 0, BYOL Loss (LARS): 0.7528
# Epoch 155, Iter 10, BYOL Loss (LARS): 0.9057
# Epoch 156, Iter 0, BYOL Loss (LARS): 0.7754
# Epoch 156, Iter 10, BYOL Loss (LARS): 0.7534
# Epoch 157, Iter 0, BYOL Loss (LARS): 0.9348
# Epoch 157, Iter 10, BYOL Loss (LARS): 0.8316
# Epoch 158, Iter 0, BYOL Loss (LARS): 0.8724
# Epoch 158, Iter 10, BYOL Loss (LARS): 0.7657
# Epoch 159, Iter 0, BYOL Loss (LARS): 0.8081
# Epoch 159, Iter 10, BYOL Loss (LARS): 0.9493
# Epoch 160, Iter 0, BYOL Loss (LARS): 0.8832
# Epoch 160, Iter 10, BYOL Loss (LARS): 0.8588
# Epoch 161, Iter 0, BYOL Loss (LARS): 0.8928
# Epoch 161, Iter 10, BYOL Loss (LARS): 0.8879
# Epoch 162, Iter 0, BYOL Loss (LARS): 0.9137
# Epoch 162, Iter 10, BYOL Loss (LARS): 0.8775
# Epoch 163, Iter 0, BYOL Loss (LARS): 0.8526
# Epoch 163, Iter 10, BYOL Loss (LARS): 0.8608
# Epoch 164, Iter 0, BYOL Loss (LARS): 0.8989
# Epoch 164, Iter 10, BYOL Loss (LARS): 0.8221
# Epoch 165, Iter 0, BYOL Loss (LARS): 0.9336
# Epoch 165, Iter 10, BYOL Loss (LARS): 0.8923
# Epoch 166, Iter 0, BYOL Loss (LARS): 0.8415
# Epoch 166, Iter 10, BYOL Loss (LARS): 0.9192
# Epoch 167, Iter 0, BYOL Loss (LARS): 0.8125
# Epoch 167, Iter 10, BYOL Loss (LARS): 0.8839
# Epoch 168, Iter 0, BYOL Loss (LARS): 0.8463
# Epoch 168, Iter 10, BYOL Loss (LARS): 0.8737
# Epoch 169, Iter 0, BYOL Loss (LARS): 0.8285
# Epoch 169, Iter 10, BYOL Loss (LARS): 0.7994
# Epoch 170, Iter 0, BYOL Loss (LARS): 0.7654
# Epoch 170, Iter 10, BYOL Loss (LARS): 0.7782
# Epoch 171, Iter 0, BYOL Loss (LARS): 0.8245
# Epoch 171, Iter 10, BYOL Loss (LARS): 0.7962
# Epoch 172, Iter 0, BYOL Loss (LARS): 0.8292
# Epoch 172, Iter 10, BYOL Loss (LARS): 0.8770
# Epoch 173, Iter 0, BYOL Loss (LARS): 0.9457
# Epoch 173, Iter 10, BYOL Loss (LARS): 1.0402
# Epoch 174, Iter 0, BYOL Loss (LARS): 0.9601
# Epoch 174, Iter 10, BYOL Loss (LARS): 0.7956
# Epoch 175, Iter 0, BYOL Loss (LARS): 0.8886
# Epoch 175, Iter 10, BYOL Loss (LARS): 0.9073
# Epoch 176, Iter 0, BYOL Loss (LARS): 0.7972
# Epoch 176, Iter 10, BYOL Loss (LARS): 0.9194
# Epoch 177, Iter 0, BYOL Loss (LARS): 0.8680
# Epoch 177, Iter 10, BYOL Loss (LARS): 0.8147
# Epoch 178, Iter 0, BYOL Loss (LARS): 0.8191
# Epoch 178, Iter 10, BYOL Loss (LARS): 0.8064
# Epoch 179, Iter 0, BYOL Loss (LARS): 0.9012
# Epoch 179, Iter 10, BYOL Loss (LARS): 0.8324
# Epoch 180, Iter 0, BYOL Loss (LARS): 0.8104
# Epoch 180, Iter 10, BYOL Loss (LARS): 0.7999
# Epoch 181, Iter 0, BYOL Loss (LARS): 0.9019
# Epoch 181, Iter 10, BYOL Loss (LARS): 0.9040
# Epoch 182, Iter 0, BYOL Loss (LARS): 0.7945
# Epoch 182, Iter 10, BYOL Loss (LARS): 0.8301
# Epoch 183, Iter 0, BYOL Loss (LARS): 0.9786
# Epoch 183, Iter 10, BYOL Loss (LARS): 0.7699
# Epoch 184, Iter 0, BYOL Loss (LARS): 0.8509
# Epoch 184, Iter 10, BYOL Loss (LARS): 0.8806
# Epoch 185, Iter 0, BYOL Loss (LARS): 0.9243
# Epoch 185, Iter 10, BYOL Loss (LARS): 0.7706
# Epoch 186, Iter 0, BYOL Loss (LARS): 0.8133
# Epoch 186, Iter 10, BYOL Loss (LARS): 0.8927
# Epoch 187, Iter 0, BYOL Loss (LARS): 0.8637
# Epoch 187, Iter 10, BYOL Loss (LARS): 0.9355
# Epoch 188, Iter 0, BYOL Loss (LARS): 0.8027
# Epoch 188, Iter 10, BYOL Loss (LARS): 0.8347
# Epoch 189, Iter 0, BYOL Loss (LARS): 0.7935
# Epoch 189, Iter 10, BYOL Loss (LARS): 0.8837
# Epoch 190, Iter 0, BYOL Loss (LARS): 0.8802
# Epoch 190, Iter 10, BYOL Loss (LARS): 0.7072
# Epoch 191, Iter 0, BYOL Loss (LARS): 0.8524
# Epoch 191, Iter 10, BYOL Loss (LARS): 0.8092
# Epoch 192, Iter 0, BYOL Loss (LARS): 0.8537
# Epoch 192, Iter 10, BYOL Loss (LARS): 0.7451
# Epoch 193, Iter 0, BYOL Loss (LARS): 0.7635
# Epoch 193, Iter 10, BYOL Loss (LARS): 0.8616
# Epoch 194, Iter 0, BYOL Loss (LARS): 0.7731
# Epoch 194, Iter 10, BYOL Loss (LARS): 0.8830
# Epoch 195, Iter 0, BYOL Loss (LARS): 0.9142
# Epoch 195, Iter 10, BYOL Loss (LARS): 0.8912
# Epoch 196, Iter 0, BYOL Loss (LARS): 0.7671
# Epoch 196, Iter 10, BYOL Loss (LARS): 0.9173
# Epoch 197, Iter 0, BYOL Loss (LARS): 0.8050
# Epoch 197, Iter 10, BYOL Loss (LARS): 0.8264
# Epoch 198, Iter 0, BYOL Loss (LARS): 0.8291
# Epoch 198, Iter 10, BYOL Loss (LARS): 0.8271
# Epoch 199, Iter 0, BYOL Loss (LARS): 0.8688
# Epoch 199, Iter 10, BYOL Loss (LARS): 0.6984
# Epoch 200, Iter 0, BYOL Loss (LARS): 0.7624
# Epoch 200, Iter 10, BYOL Loss (LARS): 0.9305
# Epoch 201, Iter 0, BYOL Loss (LARS): 0.8489
# Epoch 201, Iter 10, BYOL Loss (LARS): 0.8892
# Epoch 202, Iter 0, BYOL Loss (LARS): 0.8723
# Epoch 202, Iter 10, BYOL Loss (LARS): 0.8443
# Epoch 203, Iter 0, BYOL Loss (LARS): 0.7757
# Epoch 203, Iter 10, BYOL Loss (LARS): 0.9511
# Epoch 204, Iter 0, BYOL Loss (LARS): 0.8560
# Epoch 204, Iter 10, BYOL Loss (LARS): 0.9112
# Epoch 205, Iter 0, BYOL Loss (LARS): 0.7895
# Epoch 205, Iter 10, BYOL Loss (LARS): 0.8478
# Epoch 206, Iter 0, BYOL Loss (LARS): 0.8793
# Epoch 206, Iter 10, BYOL Loss (LARS): 0.7746
# Epoch 207, Iter 0, BYOL Loss (LARS): 0.8193
# Epoch 207, Iter 10, BYOL Loss (LARS): 0.8881
# Epoch 208, Iter 0, BYOL Loss (LARS): 0.7245
# Epoch 208, Iter 10, BYOL Loss (LARS): 0.9101
# Epoch 209, Iter 0, BYOL Loss (LARS): 0.7484
# Epoch 209, Iter 10, BYOL Loss (LARS): 0.8798
# Epoch 210, Iter 0, BYOL Loss (LARS): 0.8419
# Epoch 210, Iter 10, BYOL Loss (LARS): 0.8323
# Epoch 211, Iter 0, BYOL Loss (LARS): 1.0037
# Epoch 211, Iter 10, BYOL Loss (LARS): 0.7692
# Epoch 212, Iter 0, BYOL Loss (LARS): 0.8344
# Epoch 212, Iter 10, BYOL Loss (LARS): 0.8266
# Epoch 213, Iter 0, BYOL Loss (LARS): 0.9934
# Epoch 213, Iter 10, BYOL Loss (LARS): 0.8771
# Epoch 214, Iter 0, BYOL Loss (LARS): 0.7469
# Epoch 214, Iter 10, BYOL Loss (LARS): 0.8552
# Epoch 215, Iter 0, BYOL Loss (LARS): 0.8391
# Epoch 215, Iter 10, BYOL Loss (LARS): 0.9328
# Epoch 216, Iter 0, BYOL Loss (LARS): 0.8970
# Epoch 216, Iter 10, BYOL Loss (LARS): 0.8579
# Epoch 217, Iter 0, BYOL Loss (LARS): 0.9101
# Epoch 217, Iter 10, BYOL Loss (LARS): 0.8424
# Epoch 218, Iter 0, BYOL Loss (LARS): 0.8703
# Epoch 218, Iter 10, BYOL Loss (LARS): 0.8100
# Epoch 219, Iter 0, BYOL Loss (LARS): 0.8355
# Epoch 219, Iter 10, BYOL Loss (LARS): 0.8965
# Epoch 220, Iter 0, BYOL Loss (LARS): 0.8533
# Epoch 220, Iter 10, BYOL Loss (LARS): 0.8724
# Epoch 221, Iter 0, BYOL Loss (LARS): 0.7472
# Epoch 221, Iter 10, BYOL Loss (LARS): 0.8743
# Epoch 222, Iter 0, BYOL Loss (LARS): 0.8558
# Epoch 222, Iter 10, BYOL Loss (LARS): 0.8491
# Epoch 223, Iter 0, BYOL Loss (LARS): 0.8893
# Epoch 223, Iter 10, BYOL Loss (LARS): 0.8276
# Epoch 224, Iter 0, BYOL Loss (LARS): 0.8232
# Epoch 224, Iter 10, BYOL Loss (LARS): 0.8737
# Epoch 225, Iter 0, BYOL Loss (LARS): 0.7545
# Epoch 225, Iter 10, BYOL Loss (LARS): 0.7685
# Epoch 226, Iter 0, BYOL Loss (LARS): 0.8023
# Epoch 226, Iter 10, BYOL Loss (LARS): 0.8382
# Epoch 227, Iter 0, BYOL Loss (LARS): 0.8144
# Epoch 227, Iter 10, BYOL Loss (LARS): 0.8894
# Epoch 228, Iter 0, BYOL Loss (LARS): 0.8650
# Epoch 228, Iter 10, BYOL Loss (LARS): 0.8347
# Epoch 229, Iter 0, BYOL Loss (LARS): 0.7837
# Epoch 229, Iter 10, BYOL Loss (LARS): 0.9061
# Epoch 230, Iter 0, BYOL Loss (LARS): 0.8635
# Epoch 230, Iter 10, BYOL Loss (LARS): 0.8316
# Epoch 231, Iter 0, BYOL Loss (LARS): 0.8099
# Epoch 231, Iter 10, BYOL Loss (LARS): 0.8981
# Epoch 232, Iter 0, BYOL Loss (LARS): 0.7783
# Epoch 232, Iter 10, BYOL Loss (LARS): 0.8370
# Epoch 233, Iter 0, BYOL Loss (LARS): 0.7565
# Epoch 233, Iter 10, BYOL Loss (LARS): 0.7722
# Epoch 234, Iter 0, BYOL Loss (LARS): 0.7888
# Epoch 234, Iter 10, BYOL Loss (LARS): 0.8682
# Epoch 235, Iter 0, BYOL Loss (LARS): 0.7888
# Epoch 235, Iter 10, BYOL Loss (LARS): 0.8627
# Epoch 236, Iter 0, BYOL Loss (LARS): 0.9573
# Epoch 236, Iter 10, BYOL Loss (LARS): 0.8656
# Epoch 237, Iter 0, BYOL Loss (LARS): 0.8159
# Epoch 237, Iter 10, BYOL Loss (LARS): 0.8999
# Epoch 238, Iter 0, BYOL Loss (LARS): 0.7338
# Epoch 238, Iter 10, BYOL Loss (LARS): 0.8769
# Epoch 239, Iter 0, BYOL Loss (LARS): 0.7615
# Epoch 239, Iter 10, BYOL Loss (LARS): 0.7959
# Epoch 240, Iter 0, BYOL Loss (LARS): 0.9019
# Epoch 240, Iter 10, BYOL Loss (LARS): 0.8127
# Epoch 241, Iter 0, BYOL Loss (LARS): 0.8404
# Epoch 241, Iter 10, BYOL Loss (LARS): 0.9195
# Epoch 242, Iter 0, BYOL Loss (LARS): 0.7986
# Epoch 242, Iter 10, BYOL Loss (LARS): 0.7344
# Epoch 243, Iter 0, BYOL Loss (LARS): 0.8567
# Epoch 243, Iter 10, BYOL Loss (LARS): 0.8448
# Epoch 244, Iter 0, BYOL Loss (LARS): 0.7380
# Epoch 244, Iter 10, BYOL Loss (LARS): 0.8824
# Epoch 245, Iter 0, BYOL Loss (LARS): 0.9745
# Epoch 245, Iter 10, BYOL Loss (LARS): 0.7452
# Epoch 246, Iter 0, BYOL Loss (LARS): 0.7124
# Epoch 246, Iter 10, BYOL Loss (LARS): 0.7979
# Epoch 247, Iter 0, BYOL Loss (LARS): 0.7620
# Epoch 247, Iter 10, BYOL Loss (LARS): 0.8612
# Epoch 248, Iter 0, BYOL Loss (LARS): 0.8451
# Epoch 248, Iter 10, BYOL Loss (LARS): 0.6995
# Epoch 249, Iter 0, BYOL Loss (LARS): 0.6726
# Epoch 249, Iter 10, BYOL Loss (LARS): 0.9481
# Epoch 250, Iter 0, BYOL Loss (LARS): 0.7897
# Epoch 250, Iter 10, BYOL Loss (LARS): 0.9020
# Epoch 251, Iter 0, BYOL Loss (LARS): 0.7835
# Epoch 251, Iter 10, BYOL Loss (LARS): 0.8211
# Epoch 252, Iter 0, BYOL Loss (LARS): 0.8928
# Epoch 252, Iter 10, BYOL Loss (LARS): 0.7814
# Epoch 253, Iter 0, BYOL Loss (LARS): 0.7763
# Epoch 253, Iter 10, BYOL Loss (LARS): 0.8026
# Epoch 254, Iter 0, BYOL Loss (LARS): 0.8051
# Epoch 254, Iter 10, BYOL Loss (LARS): 0.8489
# Epoch 255, Iter 0, BYOL Loss (LARS): 0.9324
# Epoch 255, Iter 10, BYOL Loss (LARS): 0.8712
# Epoch 256, Iter 0, BYOL Loss (LARS): 0.7890
# Epoch 256, Iter 10, BYOL Loss (LARS): 0.9476
# Epoch 257, Iter 0, BYOL Loss (LARS): 0.9227
# Epoch 257, Iter 10, BYOL Loss (LARS): 0.8112
# Epoch 258, Iter 0, BYOL Loss (LARS): 0.8816
# Epoch 258, Iter 10, BYOL Loss (LARS): 0.9149
# Epoch 259, Iter 0, BYOL Loss (LARS): 0.8179
# Epoch 259, Iter 10, BYOL Loss (LARS): 0.8716
# Epoch 260, Iter 0, BYOL Loss (LARS): 0.8554
# Epoch 260, Iter 10, BYOL Loss (LARS): 0.9234
# Epoch 261, Iter 0, BYOL Loss (LARS): 0.8150
# Epoch 261, Iter 10, BYOL Loss (LARS): 0.9082
# Epoch 262, Iter 0, BYOL Loss (LARS): 0.7470
# Epoch 262, Iter 10, BYOL Loss (LARS): 0.8802
# Epoch 263, Iter 0, BYOL Loss (LARS): 0.8294
# Epoch 263, Iter 10, BYOL Loss (LARS): 0.8055
# Epoch 264, Iter 0, BYOL Loss (LARS): 0.8680
# Epoch 264, Iter 10, BYOL Loss (LARS): 0.8263
# Epoch 265, Iter 0, BYOL Loss (LARS): 0.9953
# Epoch 265, Iter 10, BYOL Loss (LARS): 0.7851
# Epoch 266, Iter 0, BYOL Loss (LARS): 0.8178
# Epoch 266, Iter 10, BYOL Loss (LARS): 0.8049
# Epoch 267, Iter 0, BYOL Loss (LARS): 0.8456
# Epoch 267, Iter 10, BYOL Loss (LARS): 0.9468
# Epoch 268, Iter 0, BYOL Loss (LARS): 0.6439
# Epoch 268, Iter 10, BYOL Loss (LARS): 0.7582
# Epoch 269, Iter 0, BYOL Loss (LARS): 0.7751
# Epoch 269, Iter 10, BYOL Loss (LARS): 0.7977
# Epoch 270, Iter 0, BYOL Loss (LARS): 0.7705
# Epoch 270, Iter 10, BYOL Loss (LARS): 0.8152
# Epoch 271, Iter 0, BYOL Loss (LARS): 0.7039
# Epoch 271, Iter 10, BYOL Loss (LARS): 0.7859
# Epoch 272, Iter 0, BYOL Loss (LARS): 0.8248
# Epoch 272, Iter 10, BYOL Loss (LARS): 0.8201
# Epoch 273, Iter 0, BYOL Loss (LARS): 0.9599
# Epoch 273, Iter 10, BYOL Loss (LARS): 0.7746
# Epoch 274, Iter 0, BYOL Loss (LARS): 0.6729
# Epoch 274, Iter 10, BYOL Loss (LARS): 0.8496
# Epoch 275, Iter 0, BYOL Loss (LARS): 0.7640
# Epoch 275, Iter 10, BYOL Loss (LARS): 0.9155
# Epoch 276, Iter 0, BYOL Loss (LARS): 0.6825
# Epoch 276, Iter 10, BYOL Loss (LARS): 0.7353
# Epoch 277, Iter 0, BYOL Loss (LARS): 0.7718
# Epoch 277, Iter 10, BYOL Loss (LARS): 0.7769
# Epoch 278, Iter 0, BYOL Loss (LARS): 0.7315
# Epoch 278, Iter 10, BYOL Loss (LARS): 0.7672
# Epoch 279, Iter 0, BYOL Loss (LARS): 0.8812
# Epoch 279, Iter 10, BYOL Loss (LARS): 0.7778
# Epoch 280, Iter 0, BYOL Loss (LARS): 0.8362
# Epoch 280, Iter 10, BYOL Loss (LARS): 0.9456
# Epoch 281, Iter 0, BYOL Loss (LARS): 0.7349
# Epoch 281, Iter 10, BYOL Loss (LARS): 1.0053
# Epoch 282, Iter 0, BYOL Loss (LARS): 0.8407
# Epoch 282, Iter 10, BYOL Loss (LARS): 0.8025
# Epoch 283, Iter 0, BYOL Loss (LARS): 0.7540
# Epoch 283, Iter 10, BYOL Loss (LARS): 0.7134
# Epoch 284, Iter 0, BYOL Loss (LARS): 0.6943
# Epoch 284, Iter 10, BYOL Loss (LARS): 0.7280
# Epoch 285, Iter 0, BYOL Loss (LARS): 0.8479
# Epoch 285, Iter 10, BYOL Loss (LARS): 0.8511
# Epoch 286, Iter 0, BYOL Loss (LARS): 0.7673
# Epoch 286, Iter 10, BYOL Loss (LARS): 1.0079
# Epoch 287, Iter 0, BYOL Loss (LARS): 0.7754
# Epoch 287, Iter 10, BYOL Loss (LARS): 0.7851
# Epoch 288, Iter 0, BYOL Loss (LARS): 0.8441
# Epoch 288, Iter 10, BYOL Loss (LARS): 0.7811
# Epoch 289, Iter 0, BYOL Loss (LARS): 0.7015
# Epoch 289, Iter 10, BYOL Loss (LARS): 0.9007
# Epoch 290, Iter 0, BYOL Loss (LARS): 0.8274
# Epoch 290, Iter 10, BYOL Loss (LARS): 0.7252
# Epoch 291, Iter 0, BYOL Loss (LARS): 0.7216
# Epoch 291, Iter 10, BYOL Loss (LARS): 0.8138
# Epoch 292, Iter 0, BYOL Loss (LARS): 0.8524
# Epoch 292, Iter 10, BYOL Loss (LARS): 0.8753
# Epoch 293, Iter 0, BYOL Loss (LARS): 0.8223
# Epoch 293, Iter 10, BYOL Loss (LARS): 0.8745
# Epoch 294, Iter 0, BYOL Loss (LARS): 0.8600
# Epoch 294, Iter 10, BYOL Loss (LARS): 0.8104
# Epoch 295, Iter 0, BYOL Loss (LARS): 0.8747
# Epoch 295, Iter 10, BYOL Loss (LARS): 0.8767
# Epoch 296, Iter 0, BYOL Loss (LARS): 0.8507
# Epoch 296, Iter 10, BYOL Loss (LARS): 0.7677
# Epoch 297, Iter 0, BYOL Loss (LARS): 0.6767
# Epoch 297, Iter 10, BYOL Loss (LARS): 0.8547
# Epoch 298, Iter 0, BYOL Loss (LARS): 0.7561
# Epoch 298, Iter 10, BYOL Loss (LARS): 0.6704
# Epoch 299, Iter 0, BYOL Loss (LARS): 0.7425
# Epoch 299, Iter 10, BYOL Loss (LARS): 0.7095
# Epoch 300, Iter 0, BYOL Loss (LARS): 0.8220
# Epoch 300, Iter 10, BYOL Loss (LARS): 0.8181
# Epoch 301, Iter 0, BYOL Loss (LARS): 0.8444
# Epoch 301, Iter 10, BYOL Loss (LARS): 0.8650
# Epoch 302, Iter 0, BYOL Loss (LARS): 0.8689
# Epoch 302, Iter 10, BYOL Loss (LARS): 0.7937
# Epoch 303, Iter 0, BYOL Loss (LARS): 0.7542
# Epoch 303, Iter 10, BYOL Loss (LARS): 0.9255
# Epoch 304, Iter 0, BYOL Loss (LARS): 0.7415
# Epoch 304, Iter 10, BYOL Loss (LARS): 0.7602
# Epoch 305, Iter 0, BYOL Loss (LARS): 0.7622
# Epoch 305, Iter 10, BYOL Loss (LARS): 0.8095
# Epoch 306, Iter 0, BYOL Loss (LARS): 0.7020
# Epoch 306, Iter 10, BYOL Loss (LARS): 0.9353
# Epoch 307, Iter 0, BYOL Loss (LARS): 0.7834
# Epoch 307, Iter 10, BYOL Loss (LARS): 0.8424
# Epoch 308, Iter 0, BYOL Loss (LARS): 0.8600
# Epoch 308, Iter 10, BYOL Loss (LARS): 0.9170
# Epoch 309, Iter 0, BYOL Loss (LARS): 0.8869
# Epoch 309, Iter 10, BYOL Loss (LARS): 0.8334
# Epoch 310, Iter 0, BYOL Loss (LARS): 0.6302
# Epoch 310, Iter 10, BYOL Loss (LARS): 0.7009
# Epoch 311, Iter 0, BYOL Loss (LARS): 0.6936
# Epoch 311, Iter 10, BYOL Loss (LARS): 0.8229
# Epoch 312, Iter 0, BYOL Loss (LARS): 0.7825
# Epoch 312, Iter 10, BYOL Loss (LARS): 0.8251
# Epoch 313, Iter 0, BYOL Loss (LARS): 0.6921
# Epoch 313, Iter 10, BYOL Loss (LARS): 0.8912
# Epoch 314, Iter 0, BYOL Loss (LARS): 0.8186
# Epoch 314, Iter 10, BYOL Loss (LARS): 1.0273
# Epoch 315, Iter 0, BYOL Loss (LARS): 0.7684
# Epoch 315, Iter 10, BYOL Loss (LARS): 0.7826
# Epoch 316, Iter 0, BYOL Loss (LARS): 0.8316
# Epoch 316, Iter 10, BYOL Loss (LARS): 0.7304
# Epoch 317, Iter 0, BYOL Loss (LARS): 0.8533
# Epoch 317, Iter 10, BYOL Loss (LARS): 0.7488
# Epoch 318, Iter 0, BYOL Loss (LARS): 0.8024
# Epoch 318, Iter 10, BYOL Loss (LARS): 0.6874
# Epoch 319, Iter 0, BYOL Loss (LARS): 0.8182
# Epoch 319, Iter 10, BYOL Loss (LARS): 0.7080
# Epoch 320, Iter 0, BYOL Loss (LARS): 0.8417
# Epoch 320, Iter 10, BYOL Loss (LARS): 0.7944
# Epoch 321, Iter 0, BYOL Loss (LARS): 0.8027
# Epoch 321, Iter 10, BYOL Loss (LARS): 0.8396
# Epoch 322, Iter 0, BYOL Loss (LARS): 0.8803
# Epoch 322, Iter 10, BYOL Loss (LARS): 0.8451
# Epoch 323, Iter 0, BYOL Loss (LARS): 0.8519
# Epoch 323, Iter 10, BYOL Loss (LARS): 0.8356
# Epoch 324, Iter 0, BYOL Loss (LARS): 0.8143
# Epoch 324, Iter 10, BYOL Loss (LARS): 0.6333
# Epoch 325, Iter 0, BYOL Loss (LARS): 0.7581
# Epoch 325, Iter 10, BYOL Loss (LARS): 0.8122
# Epoch 326, Iter 0, BYOL Loss (LARS): 0.7678
# Epoch 326, Iter 10, BYOL Loss (LARS): 0.6612
# Epoch 327, Iter 0, BYOL Loss (LARS): 0.8873
# Epoch 327, Iter 10, BYOL Loss (LARS): 0.8866
# Epoch 328, Iter 0, BYOL Loss (LARS): 0.7695
# Epoch 328, Iter 10, BYOL Loss (LARS): 0.6185
# Epoch 329, Iter 0, BYOL Loss (LARS): 0.9785
# Epoch 329, Iter 10, BYOL Loss (LARS): 0.7183
# Epoch 330, Iter 0, BYOL Loss (LARS): 0.8126
# Epoch 330, Iter 10, BYOL Loss (LARS): 0.8414
# Epoch 331, Iter 0, BYOL Loss (LARS): 0.7290
# Epoch 331, Iter 10, BYOL Loss (LARS): 0.8495
# Epoch 332, Iter 0, BYOL Loss (LARS): 0.7841
# Epoch 332, Iter 10, BYOL Loss (LARS): 0.7535
# Epoch 333, Iter 0, BYOL Loss (LARS): 0.7521
# Epoch 333, Iter 10, BYOL Loss (LARS): 0.6874
# Epoch 334, Iter 0, BYOL Loss (LARS): 0.7020
# Epoch 334, Iter 10, BYOL Loss (LARS): 0.8419
# Epoch 335, Iter 0, BYOL Loss (LARS): 0.6397
# Epoch 335, Iter 10, BYOL Loss (LARS): 0.8212
# Epoch 336, Iter 0, BYOL Loss (LARS): 0.7194
# Epoch 336, Iter 10, BYOL Loss (LARS): 0.7546
# Epoch 337, Iter 0, BYOL Loss (LARS): 0.8812
# Epoch 337, Iter 10, BYOL Loss (LARS): 0.7947
# Epoch 338, Iter 0, BYOL Loss (LARS): 0.7938
# Epoch 338, Iter 10, BYOL Loss (LARS): 0.9595
# Epoch 339, Iter 0, BYOL Loss (LARS): 0.7982
# Epoch 339, Iter 10, BYOL Loss (LARS): 0.8021
# Epoch 340, Iter 0, BYOL Loss (LARS): 0.7197
# Epoch 340, Iter 10, BYOL Loss (LARS): 0.9624
# Epoch 341, Iter 0, BYOL Loss (LARS): 0.9574
# Epoch 341, Iter 10, BYOL Loss (LARS): 0.7090
# Epoch 342, Iter 0, BYOL Loss (LARS): 0.7913
# Epoch 342, Iter 10, BYOL Loss (LARS): 0.6711
# Epoch 343, Iter 0, BYOL Loss (LARS): 0.8862
# Epoch 343, Iter 10, BYOL Loss (LARS): 0.7512
# Epoch 344, Iter 0, BYOL Loss (LARS): 0.7394
# Epoch 344, Iter 10, BYOL Loss (LARS): 0.9502
# Epoch 345, Iter 0, BYOL Loss (LARS): 0.7780
# Epoch 345, Iter 10, BYOL Loss (LARS): 0.8432
# Epoch 346, Iter 0, BYOL Loss (LARS): 0.7175
# Epoch 346, Iter 10, BYOL Loss (LARS): 0.8167
# Epoch 347, Iter 0, BYOL Loss (LARS): 0.7445
# Epoch 347, Iter 10, BYOL Loss (LARS): 0.7740
# Epoch 348, Iter 0, BYOL Loss (LARS): 0.8721
# Epoch 348, Iter 10, BYOL Loss (LARS): 0.9091
# Epoch 349, Iter 0, BYOL Loss (LARS): 0.8517
# Epoch 349, Iter 10, BYOL Loss (LARS): 0.6907
# Epoch 350, Iter 0, BYOL Loss (LARS): 0.8153
# Epoch 350, Iter 10, BYOL Loss (LARS): 0.8238
# Epoch 351, Iter 0, BYOL Loss (LARS): 0.8708
# Epoch 351, Iter 10, BYOL Loss (LARS): 0.8171
# Epoch 352, Iter 0, BYOL Loss (LARS): 0.7064
# Epoch 352, Iter 10, BYOL Loss (LARS): 0.9141
# Epoch 353, Iter 0, BYOL Loss (LARS): 0.8184
# Epoch 353, Iter 10, BYOL Loss (LARS): 0.8506
# Epoch 354, Iter 0, BYOL Loss (LARS): 0.7804
# Epoch 354, Iter 10, BYOL Loss (LARS): 0.8534
# Epoch 355, Iter 0, BYOL Loss (LARS): 0.7228
# Epoch 355, Iter 10, BYOL Loss (LARS): 0.7177
# Epoch 356, Iter 0, BYOL Loss (LARS): 0.9036
# Epoch 356, Iter 10, BYOL Loss (LARS): 0.7876
# Epoch 357, Iter 0, BYOL Loss (LARS): 0.9086
# Epoch 357, Iter 10, BYOL Loss (LARS): 0.7212
# Epoch 358, Iter 0, BYOL Loss (LARS): 0.6882
# Epoch 358, Iter 10, BYOL Loss (LARS): 0.6702
# Epoch 359, Iter 0, BYOL Loss (LARS): 0.8036
# Epoch 359, Iter 10, BYOL Loss (LARS): 0.7175
# Epoch 360, Iter 0, BYOL Loss (LARS): 0.6898
# Epoch 360, Iter 10, BYOL Loss (LARS): 0.7030
# Epoch 361, Iter 0, BYOL Loss (LARS): 0.7526
# Epoch 361, Iter 10, BYOL Loss (LARS): 0.8032
# Epoch 362, Iter 0, BYOL Loss (LARS): 0.7448
# Epoch 362, Iter 10, BYOL Loss (LARS): 0.7796
# Epoch 363, Iter 0, BYOL Loss (LARS): 0.8826
# Epoch 363, Iter 10, BYOL Loss (LARS): 0.8581
# Epoch 364, Iter 0, BYOL Loss (LARS): 0.8336
# Epoch 364, Iter 10, BYOL Loss (LARS): 0.7362
# Epoch 365, Iter 0, BYOL Loss (LARS): 0.7860
# Epoch 365, Iter 10, BYOL Loss (LARS): 0.9278
# Epoch 366, Iter 0, BYOL Loss (LARS): 0.8565
# Epoch 366, Iter 10, BYOL Loss (LARS): 0.7733
# Epoch 367, Iter 0, BYOL Loss (LARS): 0.8603
# Epoch 367, Iter 10, BYOL Loss (LARS): 0.7583
# Epoch 368, Iter 0, BYOL Loss (LARS): 0.7857
# Epoch 368, Iter 10, BYOL Loss (LARS): 0.8174
# Epoch 369, Iter 0, BYOL Loss (LARS): 1.0054
# Epoch 369, Iter 10, BYOL Loss (LARS): 0.7657
# Epoch 370, Iter 0, BYOL Loss (LARS): 0.5939
# Epoch 370, Iter 10, BYOL Loss (LARS): 0.6448
# Epoch 371, Iter 0, BYOL Loss (LARS): 0.9265
# Epoch 371, Iter 10, BYOL Loss (LARS): 0.9357
# Epoch 372, Iter 0, BYOL Loss (LARS): 0.8304
# Epoch 372, Iter 10, BYOL Loss (LARS): 0.7467
# Epoch 373, Iter 0, BYOL Loss (LARS): 0.7901
# Epoch 373, Iter 10, BYOL Loss (LARS): 0.8702
# Epoch 374, Iter 0, BYOL Loss (LARS): 0.7336
# Epoch 374, Iter 10, BYOL Loss (LARS): 0.7848
# Epoch 375, Iter 0, BYOL Loss (LARS): 0.7796
# Epoch 375, Iter 10, BYOL Loss (LARS): 0.6971
# Epoch 376, Iter 0, BYOL Loss (LARS): 0.7711
# Epoch 376, Iter 10, BYOL Loss (LARS): 0.7532
# Epoch 377, Iter 0, BYOL Loss (LARS): 0.6599
# Epoch 377, Iter 10, BYOL Loss (LARS): 0.8345
# Epoch 378, Iter 0, BYOL Loss (LARS): 0.8565
# Epoch 378, Iter 10, BYOL Loss (LARS): 0.8987
# Epoch 379, Iter 0, BYOL Loss (LARS): 0.8098
# Epoch 379, Iter 10, BYOL Loss (LARS): 0.7153
# Epoch 380, Iter 0, BYOL Loss (LARS): 0.7790
# Epoch 380, Iter 10, BYOL Loss (LARS): 0.8134
# Epoch 381, Iter 0, BYOL Loss (LARS): 0.7642
# Epoch 381, Iter 10, BYOL Loss (LARS): 0.6977
# Epoch 382, Iter 0, BYOL Loss (LARS): 0.8911
# Epoch 382, Iter 10, BYOL Loss (LARS): 0.8471
# Epoch 383, Iter 0, BYOL Loss (LARS): 0.8627
# Epoch 383, Iter 10, BYOL Loss (LARS): 0.8838
# Epoch 384, Iter 0, BYOL Loss (LARS): 0.8831
# Epoch 384, Iter 10, BYOL Loss (LARS): 0.8655
# Epoch 385, Iter 0, BYOL Loss (LARS): 0.7561
# Epoch 385, Iter 10, BYOL Loss (LARS): 0.7740
# Epoch 386, Iter 0, BYOL Loss (LARS): 0.8750
# Epoch 386, Iter 10, BYOL Loss (LARS): 0.7460
# Epoch 387, Iter 0, BYOL Loss (LARS): 0.8557
# Epoch 387, Iter 10, BYOL Loss (LARS): 0.7474
# Epoch 388, Iter 0, BYOL Loss (LARS): 0.8672
# Epoch 388, Iter 10, BYOL Loss (LARS): 0.7998
# Epoch 389, Iter 0, BYOL Loss (LARS): 0.8265
# Epoch 389, Iter 10, BYOL Loss (LARS): 0.8719
# Epoch 390, Iter 0, BYOL Loss (LARS): 0.8850
# Epoch 390, Iter 10, BYOL Loss (LARS): 0.7182
# Epoch 391, Iter 0, BYOL Loss (LARS): 0.8535
# Epoch 391, Iter 10, BYOL Loss (LARS): 0.7969
# Epoch 392, Iter 0, BYOL Loss (LARS): 0.8008
# Epoch 392, Iter 10, BYOL Loss (LARS): 0.6767
# Epoch 393, Iter 0, BYOL Loss (LARS): 0.9233
# Epoch 393, Iter 10, BYOL Loss (LARS): 0.8208
# Epoch 394, Iter 0, BYOL Loss (LARS): 0.7317
# Epoch 394, Iter 10, BYOL Loss (LARS): 0.8083
# Epoch 395, Iter 0, BYOL Loss (LARS): 0.6967
# Epoch 395, Iter 10, BYOL Loss (LARS): 0.7214
# Epoch 396, Iter 0, BYOL Loss (LARS): 0.9048
# Epoch 396, Iter 10, BYOL Loss (LARS): 0.8525
# Epoch 397, Iter 0, BYOL Loss (LARS): 0.7832
# Epoch 397, Iter 10, BYOL Loss (LARS): 0.7347
# Epoch 398, Iter 0, BYOL Loss (LARS): 0.6918
# Epoch 398, Iter 10, BYOL Loss (LARS): 0.7925
# Epoch 399, Iter 0, BYOL Loss (LARS): 0.7259
# Epoch 399, Iter 10, BYOL Loss (LARS): 0.8937
# Epoch 400, Iter 0, BYOL Loss (LARS): 0.7919
# Epoch 400, Iter 10, BYOL Loss (LARS): 0.8771
# Epoch 401, Iter 0, BYOL Loss (LARS): 0.6293
# Epoch 401, Iter 10, BYOL Loss (LARS): 0.7449
# Epoch 402, Iter 0, BYOL Loss (LARS): 0.8834
# Epoch 402, Iter 10, BYOL Loss (LARS): 0.6505
# Epoch 403, Iter 0, BYOL Loss (LARS): 0.7408
# Epoch 403, Iter 10, BYOL Loss (LARS): 0.7658
# Epoch 404, Iter 0, BYOL Loss (LARS): 0.7836
# Epoch 404, Iter 10, BYOL Loss (LARS): 0.7296
# Epoch 405, Iter 0, BYOL Loss (LARS): 0.7887
# Epoch 405, Iter 10, BYOL Loss (LARS): 0.8421
# Epoch 406, Iter 0, BYOL Loss (LARS): 0.8302
# Epoch 406, Iter 10, BYOL Loss (LARS): 0.9064
# Epoch 407, Iter 0, BYOL Loss (LARS): 0.8389
# Epoch 407, Iter 10, BYOL Loss (LARS): 0.8810
# Epoch 408, Iter 0, BYOL Loss (LARS): 0.8642
# Epoch 408, Iter 10, BYOL Loss (LARS): 0.7998
# Epoch 409, Iter 0, BYOL Loss (LARS): 0.6821
# Epoch 409, Iter 10, BYOL Loss (LARS): 0.8104
# Epoch 410, Iter 0, BYOL Loss (LARS): 0.7556
# Epoch 410, Iter 10, BYOL Loss (LARS): 0.9151
# Epoch 411, Iter 0, BYOL Loss (LARS): 0.7469
# Epoch 411, Iter 10, BYOL Loss (LARS): 0.9195
# Epoch 412, Iter 0, BYOL Loss (LARS): 0.7775
# Epoch 412, Iter 10, BYOL Loss (LARS): 0.6977
# Epoch 413, Iter 0, BYOL Loss (LARS): 0.8800
# Epoch 413, Iter 10, BYOL Loss (LARS): 0.6731
# Epoch 414, Iter 0, BYOL Loss (LARS): 0.6615
# Epoch 414, Iter 10, BYOL Loss (LARS): 0.8033
# Epoch 415, Iter 0, BYOL Loss (LARS): 0.8794
# Epoch 415, Iter 10, BYOL Loss (LARS): 0.9127
# Epoch 416, Iter 0, BYOL Loss (LARS): 0.7854
# Epoch 416, Iter 10, BYOL Loss (LARS): 0.8621
# Epoch 417, Iter 0, BYOL Loss (LARS): 0.7174
# Epoch 417, Iter 10, BYOL Loss (LARS): 0.8765
# Epoch 418, Iter 0, BYOL Loss (LARS): 0.8465
# Epoch 418, Iter 10, BYOL Loss (LARS): 0.7857
# Epoch 419, Iter 0, BYOL Loss (LARS): 0.7260
# Epoch 419, Iter 10, BYOL Loss (LARS): 0.7645
# Epoch 420, Iter 0, BYOL Loss (LARS): 0.8866
# Epoch 420, Iter 10, BYOL Loss (LARS): 0.7722
# Epoch 421, Iter 0, BYOL Loss (LARS): 0.6972
# Epoch 421, Iter 10, BYOL Loss (LARS): 0.8445
# Epoch 422, Iter 0, BYOL Loss (LARS): 0.7200
# Epoch 422, Iter 10, BYOL Loss (LARS): 0.7568
# Epoch 423, Iter 0, BYOL Loss (LARS): 0.9058
# Epoch 423, Iter 10, BYOL Loss (LARS): 0.7641
# Epoch 424, Iter 0, BYOL Loss (LARS): 0.8643
# Epoch 424, Iter 10, BYOL Loss (LARS): 0.8144
# Epoch 425, Iter 0, BYOL Loss (LARS): 0.7979
# Epoch 425, Iter 10, BYOL Loss (LARS): 0.8230
# Epoch 426, Iter 0, BYOL Loss (LARS): 0.7278
# Epoch 426, Iter 10, BYOL Loss (LARS): 0.7272
# Epoch 427, Iter 0, BYOL Loss (LARS): 0.8189
# Epoch 427, Iter 10, BYOL Loss (LARS): 0.7314
# Epoch 428, Iter 0, BYOL Loss (LARS): 0.7314
# Epoch 428, Iter 10, BYOL Loss (LARS): 0.7223
# Epoch 429, Iter 0, BYOL Loss (LARS): 0.8076
# Epoch 429, Iter 10, BYOL Loss (LARS): 0.7130
# Epoch 430, Iter 0, BYOL Loss (LARS): 0.7180
# Epoch 430, Iter 10, BYOL Loss (LARS): 0.7713
# Epoch 431, Iter 0, BYOL Loss (LARS): 0.9098
# Epoch 431, Iter 10, BYOL Loss (LARS): 0.7721
# Epoch 432, Iter 0, BYOL Loss (LARS): 0.8064
# Epoch 432, Iter 10, BYOL Loss (LARS): 0.8101
# Epoch 433, Iter 0, BYOL Loss (LARS): 0.9023
# Epoch 433, Iter 10, BYOL Loss (LARS): 0.8448
# Epoch 434, Iter 0, BYOL Loss (LARS): 0.7412
# Epoch 434, Iter 10, BYOL Loss (LARS): 0.6798
# Epoch 435, Iter 0, BYOL Loss (LARS): 0.7288
# Epoch 435, Iter 10, BYOL Loss (LARS): 0.7472
# Epoch 436, Iter 0, BYOL Loss (LARS): 0.7300
# Epoch 436, Iter 10, BYOL Loss (LARS): 0.7021
# Epoch 437, Iter 0, BYOL Loss (LARS): 0.8036
# Epoch 437, Iter 10, BYOL Loss (LARS): 0.7681
# Epoch 438, Iter 0, BYOL Loss (LARS): 0.7304
# Epoch 438, Iter 10, BYOL Loss (LARS): 0.6673
# Epoch 439, Iter 0, BYOL Loss (LARS): 0.7130
# Epoch 439, Iter 10, BYOL Loss (LARS): 0.8071
# Epoch 440, Iter 0, BYOL Loss (LARS): 0.7424
# Epoch 440, Iter 10, BYOL Loss (LARS): 0.7831
# Epoch 441, Iter 0, BYOL Loss (LARS): 0.8099
# Epoch 441, Iter 10, BYOL Loss (LARS): 0.6575
# Epoch 442, Iter 0, BYOL Loss (LARS): 0.7549
# Epoch 442, Iter 10, BYOL Loss (LARS): 0.7755
# Epoch 443, Iter 0, BYOL Loss (LARS): 0.8046
# Epoch 443, Iter 10, BYOL Loss (LARS): 0.6859
# Epoch 444, Iter 0, BYOL Loss (LARS): 0.8063
# Epoch 444, Iter 10, BYOL Loss (LARS): 0.8926
# Epoch 445, Iter 0, BYOL Loss (LARS): 0.8000
# Epoch 445, Iter 10, BYOL Loss (LARS): 0.7308
# Epoch 446, Iter 0, BYOL Loss (LARS): 0.7762
# Epoch 446, Iter 10, BYOL Loss (LARS): 0.8175
# Epoch 447, Iter 0, BYOL Loss (LARS): 0.6953
# Epoch 447, Iter 10, BYOL Loss (LARS): 0.7948
# Epoch 448, Iter 0, BYOL Loss (LARS): 0.8697
# Epoch 448, Iter 10, BYOL Loss (LARS): 0.8486
# Epoch 449, Iter 0, BYOL Loss (LARS): 0.7152
# Epoch 449, Iter 10, BYOL Loss (LARS): 0.7185
# Epoch 450, Iter 0, BYOL Loss (LARS): 0.6983
# Epoch 450, Iter 10, BYOL Loss (LARS): 0.8815
# Epoch 451, Iter 0, BYOL Loss (LARS): 0.7008
# Epoch 451, Iter 10, BYOL Loss (LARS): 0.8287
# Epoch 452, Iter 0, BYOL Loss (LARS): 0.7265
# Epoch 452, Iter 10, BYOL Loss (LARS): 0.9443
# Epoch 453, Iter 0, BYOL Loss (LARS): 0.8270
# Epoch 453, Iter 10, BYOL Loss (LARS): 0.9118
# Epoch 454, Iter 0, BYOL Loss (LARS): 0.6850
# Epoch 454, Iter 10, BYOL Loss (LARS): 0.8957
# Epoch 455, Iter 0, BYOL Loss (LARS): 0.9359
# Epoch 455, Iter 10, BYOL Loss (LARS): 0.6082
# Epoch 456, Iter 0, BYOL Loss (LARS): 0.7977
# Epoch 456, Iter 10, BYOL Loss (LARS): 0.8132
# Epoch 457, Iter 0, BYOL Loss (LARS): 0.7624
# Epoch 457, Iter 10, BYOL Loss (LARS): 0.8232
# Epoch 458, Iter 0, BYOL Loss (LARS): 0.8643
# Epoch 458, Iter 10, BYOL Loss (LARS): 0.7228
# Epoch 459, Iter 0, BYOL Loss (LARS): 0.7654
# Epoch 459, Iter 10, BYOL Loss (LARS): 0.7334
# Epoch 460, Iter 0, BYOL Loss (LARS): 0.7121
# Epoch 460, Iter 10, BYOL Loss (LARS): 0.8610
# Epoch 461, Iter 0, BYOL Loss (LARS): 0.7902
# Epoch 461, Iter 10, BYOL Loss (LARS): 0.7306
# Epoch 462, Iter 0, BYOL Loss (LARS): 0.8302
# Epoch 462, Iter 10, BYOL Loss (LARS): 0.6476
# Epoch 463, Iter 0, BYOL Loss (LARS): 0.8705
# Epoch 463, Iter 10, BYOL Loss (LARS): 0.7534
# Epoch 464, Iter 0, BYOL Loss (LARS): 0.6964
# Epoch 464, Iter 10, BYOL Loss (LARS): 0.7123
# Epoch 465, Iter 0, BYOL Loss (LARS): 0.7447
# Epoch 465, Iter 10, BYOL Loss (LARS): 0.8649
# Epoch 466, Iter 0, BYOL Loss (LARS): 0.9007
# Epoch 466, Iter 10, BYOL Loss (LARS): 0.8012
# Epoch 467, Iter 0, BYOL Loss (LARS): 0.7606
# Epoch 467, Iter 10, BYOL Loss (LARS): 0.8036
# Epoch 468, Iter 0, BYOL Loss (LARS): 0.8342
# Epoch 468, Iter 10, BYOL Loss (LARS): 0.7624
# Epoch 469, Iter 0, BYOL Loss (LARS): 0.7501
# Epoch 469, Iter 10, BYOL Loss (LARS): 0.8407
# Epoch 470, Iter 0, BYOL Loss (LARS): 0.8297
# Epoch 470, Iter 10, BYOL Loss (LARS): 1.0749
# Epoch 471, Iter 0, BYOL Loss (LARS): 0.8237
# Epoch 471, Iter 10, BYOL Loss (LARS): 0.8544
# Epoch 472, Iter 0, BYOL Loss (LARS): 0.8212
# Epoch 472, Iter 10, BYOL Loss (LARS): 0.7875
# Epoch 473, Iter 0, BYOL Loss (LARS): 0.8682
# Epoch 473, Iter 10, BYOL Loss (LARS): 0.8632
# Epoch 474, Iter 0, BYOL Loss (LARS): 0.6883
# Epoch 474, Iter 10, BYOL Loss (LARS): 0.7852
# Epoch 475, Iter 0, BYOL Loss (LARS): 0.7270
# Epoch 475, Iter 10, BYOL Loss (LARS): 0.8378
# Epoch 476, Iter 0, BYOL Loss (LARS): 0.7509
# Epoch 476, Iter 10, BYOL Loss (LARS): 0.7604
# Epoch 477, Iter 0, BYOL Loss (LARS): 0.6999
# Epoch 477, Iter 10, BYOL Loss (LARS): 0.7520
# Epoch 478, Iter 0, BYOL Loss (LARS): 0.8440
# Epoch 478, Iter 10, BYOL Loss (LARS): 0.7557
# Epoch 479, Iter 0, BYOL Loss (LARS): 0.6977
# Epoch 479, Iter 10, BYOL Loss (LARS): 0.6962
# Epoch 480, Iter 0, BYOL Loss (LARS): 0.7032
# Epoch 480, Iter 10, BYOL Loss (LARS): 0.7460
# Epoch 481, Iter 0, BYOL Loss (LARS): 0.8110
# Epoch 481, Iter 10, BYOL Loss (LARS): 0.7814
# Epoch 482, Iter 0, BYOL Loss (LARS): 0.9027
# Epoch 482, Iter 10, BYOL Loss (LARS): 0.8159
# Epoch 483, Iter 0, BYOL Loss (LARS): 0.7837
# Epoch 483, Iter 10, BYOL Loss (LARS): 0.7718
# Epoch 484, Iter 0, BYOL Loss (LARS): 0.7004
# Epoch 484, Iter 10, BYOL Loss (LARS): 0.8585
# Epoch 485, Iter 0, BYOL Loss (LARS): 0.7860
# Epoch 485, Iter 10, BYOL Loss (LARS): 0.6834
# Epoch 486, Iter 0, BYOL Loss (LARS): 0.8403
# Epoch 486, Iter 10, BYOL Loss (LARS): 0.8118
# Epoch 487, Iter 0, BYOL Loss (LARS): 0.8418
# Epoch 487, Iter 10, BYOL Loss (LARS): 0.7768
# Epoch 488, Iter 0, BYOL Loss (LARS): 0.8381
# Epoch 488, Iter 10, BYOL Loss (LARS): 0.7581
# Epoch 489, Iter 0, BYOL Loss (LARS): 0.7214
# Epoch 489, Iter 10, BYOL Loss (LARS): 0.6633
# Epoch 490, Iter 0, BYOL Loss (LARS): 0.8072
# Epoch 490, Iter 10, BYOL Loss (LARS): 0.6729
# Epoch 491, Iter 0, BYOL Loss (LARS): 0.7725
# Epoch 491, Iter 10, BYOL Loss (LARS): 0.6983
# Epoch 492, Iter 0, BYOL Loss (LARS): 0.6606
# Epoch 492, Iter 10, BYOL Loss (LARS): 0.7490
# Epoch 493, Iter 0, BYOL Loss (LARS): 0.7663
# Epoch 493, Iter 10, BYOL Loss (LARS): 0.7140
# Epoch 494, Iter 0, BYOL Loss (LARS): 0.7641
# Epoch 494, Iter 10, BYOL Loss (LARS): 0.7235
# Epoch 495, Iter 0, BYOL Loss (LARS): 0.7585
# Epoch 495, Iter 10, BYOL Loss (LARS): 0.8361
# Epoch 496, Iter 0, BYOL Loss (LARS): 0.7365
# Epoch 496, Iter 10, BYOL Loss (LARS): 0.8151
# Epoch 497, Iter 0, BYOL Loss (LARS): 0.7779
# Epoch 497, Iter 10, BYOL Loss (LARS): 0.6333
# Epoch 498, Iter 0, BYOL Loss (LARS): 0.7805
# Epoch 498, Iter 10, BYOL Loss (LARS): 0.7818
# Epoch 499, Iter 0, BYOL Loss (LARS): 0.8991
# Epoch 499, Iter 10, BYOL Loss (LARS): 0.7619
# Weights saved to runs/Mar19_13-04-43_59089b681045/original_byol_lars.pth
#
# --- Linear Evaluation (Frozen ResNet-50) ---
# Epoch 0 | Accuracy: 30.79%
# Epoch 10 | Accuracy: 36.04%
# Epoch 20 | Accuracy: 34.80%
# Epoch 30 | Accuracy: 38.74%
# Epoch 40 | Accuracy: 37.85%
# Epoch 50 | Accuracy: 37.36%
# Epoch 60 | Accuracy: 39.36%
# Epoch 70 | Accuracy: 39.35%
# Epoch 80 | Accuracy: 39.18%
# Epoch 90 | Accuracy: 38.84%
